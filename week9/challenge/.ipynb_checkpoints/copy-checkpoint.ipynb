# %% [markdown]
# # Predicting ENEM trainees with RandomForestClassifier

# %% [markdown]
# The ENEM(National High School Exam, in english) is a test carried out by the National Institute of Educational Studies and Research Anísio Teixeira, an agency linked to the Ministry of Education of Brazil, and was created in 1998. It is used to assess the quality of high school in the country and to admission to universities.
#
# Some students decide to take the ENEM test before finishing high school, as a test. This type of student is known as "trainee" and the IN_TREINEIRO column is the column that informs us about this characteristic.
#
# In this challenge, we will use a binary classification model to infer whether a student is a trainer or not, with our results being 1 or 0 for trainer or not.

# %% [markdown]
# ## General Setup

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# ## EDA and Feature Selection

# %% [markdown]
# First, let's look at the correlation table.

# %%
df_train.corr()['IN_TREINEIRO'].sort_values(ascending=False).head(10)
# Out:
# IN_TREINEIRO       1.000000
# TP_ST_CONCLUSAO    0.533983
# TP_PRESENCA_CN     0.094692
# TP_PRESENCA_CH     0.094692
# TP_PRESENCA_LC     0.092454
# TP_PRESENCA_MT     0.092454
# Q034               0.055265
# Q039               0.040348
# Q005               0.033411
# Q038               0.018855
# Name: IN_TREINEIRO, dtype: float64

# %% [markdown]
# Looking at the table it would make sense to choose only ```'TP_ST_CONCLUSAO'``` for training the model. However, after reading the features dictionary and using previous knowledge about the ENEM, it seems interesting to us to use the students' ages described in ```NU_IDADE``` to perform this classification as well.
#
# Just in case, let's test each situation.

# %%
def evaluate_classifier(X, y):
    # Make a train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=777)
    # Train the RF Classifier
    rf_clf = RandomForestClassifier(max_depth=2, random_state=777)
    rf_clf.fit(X_train, y_train)
    # Predict 'IN_TREINEIRO'
    y_pred = rf_clf.predict(X_test)
    
    # Calculate F1 Score
    print(f'F1 score:{f1_score(y_test, y_pred)}')
    
    # Plot ROC curve
    fpr, tpr, threshold = roc_curve(y_test, y_pred)
    roc_auc = auc(fpr, tpr)
                       
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
evaluate_classifier(df_train[['TP_ST_CONCLUSAO']], df_train['IN_TREINEIRO'])
# Out:
# [0 0 1 ... 0 0 0]
# F1 score:0.8639405204460967

# %%
evaluate_classifier(df_train[['TP_ST_CONCLUSAO', 'NU_IDADE']], df_train['IN_TREINEIRO'])
# Out:
# F1 score:0.9835497835497835

# %% [markdown]
# Well, as you can see, using also ```NU_IDADE``` as a feature provided better results, so let's continue with this set of features.

# %% [markdown]
# As we have separate dataset to use in submitting the challenge, we can retrain our model using all the observations this time.
#
# Also, we will adapt our answer to the required conditions: we must save the answer in a file called answer.csv with two columns: ```NU_INSCRICAO``` and ```IN_TREINEIRO```.

# %%
X = df_train[['TP_ST_CONCLUSAO', 'NU_IDADE']]
y = df_train['IN_TREINEIRO']

# %%
rf_clf = RandomForestClassifier(max_depth=2, random_state=777)
rf_clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=2, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=777,
#                        verbose=0, warm_start=False)

# %%
y_pred = rf_clf.predict(df_test[['NU_IDADE', 'TP_ST_CONCLUSAO']])

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
df_test = df_test[['NU_INSCRICAO']]

# %%
df_test['IN_TREINEIRO']=y_pred

# %%
df_test
# Out:
#                                   NU_INSCRICAO  IN_TREINEIRO
# 0     ba0cc30ba34e7a46764c09dfc38ed83d15828897             1
# 1     177f281c68fa032aedbd842a745da68490926cd2             1
# 2     6cf0d8b97597d7625cdedc7bdb6c0f052286c334             1
# 3     5c356d810fa57671402502cd0933e5601a2ebf1e             1
# 4     df47c07bd881c2db3f38c6048bf77c132ad0ceb3             1
# ...                                        ...           ...
# 4565  361b7fcd8867119550fe2af5aa729ffad89a7cf5             1
# 4566  d8a0e4c9e29494cc9bba2422bd79333931475ee1             1
# 4567  3f1c3388244df8d6521e983a809292d9f3bca643             1
# 4568  1778e9c4cef591beb6b986d191d15ed05de816b0             1
# 4569  096809759695097e384e766d2d9e23a34fc81610             1
#
# [4570 rows x 2 columns]
