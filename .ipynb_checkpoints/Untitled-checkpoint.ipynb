# %%
#Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib
from sklearn.naive_bayes import GaussianNB

# %matplotlib inline
# Out:
# C:\Users\PC114\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Reading dataset
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
#Exploratory analysis
df_train.head()
# Out:
#    Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0           1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1           2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2           3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
# 3           4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016
# 4           5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016
#
#    CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                  4314902            Porto Alegre                43
# 1                  2304707                  Granja                23
# 2                  2304400               Fortaleza                23
# 3                  3304557          Rio de Janeiro                33
# 4                  1302603                  Manaus                13
#
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  ...  Q041  Q042  Q043  \
# 0               RS        24       M              0.0  ...   5.0     A     A
# ...

# %%
df_train['NU_IDADE'].describe()
# Out:
# count    13730.000000
# mean        21.593809
# std          7.043654
# min         13.000000
# 25%         17.000000
# 50%         19.000000
# 75%         23.000000
# max         67.000000
# Name: NU_IDADE, dtype: float64

# %%
fig, axes = plt.subplots()
sns.countplot(x='TP_SEXO', data=df_train)

# %%
fig, axes = plt.subplots(1, 5, figsize=(28, 4))
sns.kdeplot(df_train['NU_NOTA_LC'], ax = axes[0], shade=True, color='r')
sns.kdeplot(df_train['NU_NOTA_CH'], ax = axes[1], shade=True, color='rebeccapurple')
sns.kdeplot(df_train['NU_NOTA_CN'], ax = axes[2], shade=True, color='g')
sns.kdeplot(df_train['NU_NOTA_MT'], ax = axes[3], shade=True)
sns.kdeplot(df_train['NU_NOTA_REDACAO'], ax = axes[4], shade=True, color='grey')
axes[0].set_title('LINGUAGENS')
axes[1].set_title('HUMANAS')
axes[2].set_title('NATUREZA')
axes[3].set_title('MATEMATICA')
axes[4].set_title('REDACAO')
# Out:
# C:\Users\PC114\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\PC114\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# Text(0.5, 1.0, 'REDACAO')

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, square=True);

# %%
features = ['NU_NOTA_LC', 'NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_REDACAO']
df_train[features].corr()
# Out:
#                  NU_NOTA_LC  NU_NOTA_CH  NU_NOTA_CN  NU_NOTA_REDACAO
# NU_NOTA_LC         1.000000    0.692988    0.545667         0.512908
# NU_NOTA_CH         0.692988    1.000000    0.609543         0.550582
# NU_NOTA_CN         0.545667    0.609543    1.000000         0.459938
# NU_NOTA_REDACAO    0.512908    0.550582    0.459938         1.000000

# %%
df_train = df_train.loc[(df_train['NU_NOTA_LC'].notnull()) & (df_train['NU_NOTA_CH'].notnull()) & (df_train['NU_NOTA_CN'].notnull()) & (df_train['NU_NOTA_MT'].notnull()) & (df_train['NU_NOTA_REDACAO'].notnull())]

# %%
df_train = df_train[['NU_NOTA_LC', 'NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']]
df_test = df_test[['NU_NOTA_LC', 'NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_REDACAO']]

# %%
df_train['NU_NOTA_LC'].fillna(df_train['NU_NOTA_LC'].mean(), inplace=True)
df_train['NU_NOTA_CH'].fillna(df_train['NU_NOTA_CH'].mean(), inplace=True)
df_train['NU_NOTA_CN'].fillna(df_train['NU_NOTA_CN'].mean(), inplace=True)
df_train['NU_NOTA_REDACAO'].fillna(df_train['NU_NOTA_REDACAO'].mean(), inplace=True)
#df_train['TP_DEPENDENCIA_ADM_ESC'].fillna(df_train['TP_DEPENDENCIA_ADM_ESC'].mean(), inplace=True)
df_test['NU_NOTA_LC'].fillna(df_train['NU_NOTA_LC'].mean(), inplace=True)
df_test['NU_NOTA_CH'].fillna(df_train['NU_NOTA_CH'].mean(), inplace=True)
df_test['NU_NOTA_CN'].fillna(df_train['NU_NOTA_CN'].mean(), inplace=True)
df_test['NU_NOTA_REDACAO'].fillna(df_train['NU_NOTA_REDACAO'].mean(), inplace=True)
#df_train['TP_DEPENDENCIA_ADM_ESC'].fillna(df_train['TP_DEPENDENCIA_ADM_ESC'].mean(), inplace=True)

# %%
type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %%
y = df_train['NU_NOTA_MT']
x_train = df_train[features]
x_test = df_test[features]
x_test
# Out:
#       NU_NOTA_LC  NU_NOTA_CH  NU_NOTA_CN  NU_NOTA_REDACAO
# 0     431.800000  443.500000  464.800000       420.000000
# 1     548.000000  491.100000  391.100000       580.000000
# 2     613.600000  622.700000  595.900000       320.000000
# 3     516.665059  530.346123  473.912509       529.452907
# 4     571.400000  492.600000  592.900000       320.000000
# ...          ...         ...         ...              ...
# 4571  511.600000  558.200000  398.300000       500.000000
# 4572  471.100000  579.700000  427.600000       520.000000
# 4573  604.900000  643.800000  639.200000       640.000000
# 4574  540.200000  467.900000  427.100000       520.000000
# 4575  516.665059  530.346123  473.912509       529.452907
#
# [4576 rows x 4 columns]

# %% [markdown]
# reg = linear_model.LinearRegression()
# features = df_train[['NU_NOTA_LC', 'NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_REDACAO']]
# reg.fit(features, df_train['NU_NOTA_MT'])

# %% [markdown]
# reg.predict(features)

# %% [markdown]
# fig, axes = plt.subplots()
# sns.kdeplot(reg.predict(features), shade=True, color='r')
# sns.kdeplot(df_train['NU_NOTA_MT'], shade=True, color='g')

# %%
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler().fit(x_train)

# %%
x_train_scaled = scaler.transform(x_train)
x_train_scaled.std(axis=1)
# Out:
# array([0.59054157, 0.45956783, 0.91552892, ..., 0.38006678, 0.81875225,
#        0.3133266 ])

# %%
pipeline = make_pipeline(preprocessing.StandardScaler(), RandomForestRegressor(n_estimators=200, n_jobs=-1, warm_start=True))

# %%
hyperparameters = {'randomforestregressor__max_features': ['auto', 'sqrt', 'log2'], 'randomforestregressor__max_depth': [None, 5, 3, 1]}

# %%
clf = GridSearchCV(pipeline, hyperparameters, cv=10)
clf.fit(x_train_scaled, y)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor(bootstrap=True,
#                                                               ccp_alpha=0.0,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               max_samples=None,
# ...

# %%
print(clf.best_params_)
# Out:
# {'randomforestregressor__max_depth': 5, 'randomforestregressor__max_features': 'log2'}

# %%
pred = clf.predict(x_test)
from sklearn.preprocessing import normalize
normalize(pred[:, newaxis])
# Out:
# array([809.43400613, 809.43400613, 809.43400613, ..., 809.43400613,
#        809.43400613, 809.43400613])

# %%
df_resposta = pd.DataFrame()
df_resposta['NU_NOTA_MT'] = np.around(np.sort(pred), 2)

# %%
fig, axes = plt.subplots()
sns.kdeplot(df_resposta['NU_NOTA_MT'], shade=True, color='g')

# %%
df_resposta['NU_NOTA_MT'].unique()
# Out:
# array([486.18, 545.95, 746.32, 746.85, 806.31, 809.43])

# %%
df_resposta.to_csv('x2d.csv', index=False, header=True)
